# %%
CATALOG = "xml_framework"
RAW_SCHEMA = "raw"
BRONZE_SCHEMA ="bronze"
CONFIG_SCHEMA = "config"

# %% [markdown]
# VOLUMES and tables CONFIG

# %%
XSD_VOLUME = (f"/Volumes/{CATALOG}/{RAW_SCHEMA}/xsd_volume")
XML_VOLUME = (f"/Volumes/{CATALOG}/{RAW_SCHEMA}/xml_volume")
ARCHIVE_VOLUME = (f"/Volumes/{CATALOG}/{RAW_SCHEMA}/archive_volume")
# table 
SCHEMA_REGISTRY_TABLE = (f"{CATALOG}.{CONFIG_SCHEMA}.schema_registry")
