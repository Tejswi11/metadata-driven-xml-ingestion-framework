# %%
#
# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/notebooks/00_framework_config.ipynb

print(CATALOG)
print(BRONZE_SCHEMA)
print(XSD_VOLUME)

# %%
#
# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/utils/xsd_parser.ipynb

# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/utils/datatype_mapper.ipynb

# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/utils/schema_registry.ipynb

# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/utils/ddl_generator.ipynb

# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/utils/table_creator.ipynb

# %%
display(
    dbutils.fs.ls(XSD_VOLUME)
)

# %%
xsd_path = f"{XSD_VOLUME}/v1_orders.xsd"

metadata_df = extract_metadata(
    xsd_path
)

display(metadata_df)

# %%
mapped_df = map_xsd_to_sql(
    metadata_df
)

display(mapped_df)

# %%
registry_df = enrich_registry_metadata(
    mapped_df,
    xsd_file="v1_orders.xsd",
    root_element="Orders",
    target_table="v1_orders",
    schema_version=1
)

display(registry_df)

# %%
#
# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/notebooks/00_framework_config.ipynb

print(XML_VOLUME)

# %%
display(
    dbutils.fs.ls(XML_VOLUME)
)

# %%
#
# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/utils/file_archiver.ipynb

# %%
display(dbutils.fs.ls(XML_VOLUME))

# %%
v1_file = (
    "dbfs:/Volumes/xml_framework/raw/xml_volume/v1_order_1.xml"
)

# %%
archive_file(
    v1_file,
    ARCHIVE_VOLUME
)

# %%
display(
    dbutils.fs.ls(XML_VOLUME)
)

# %%
display(
    dbutils.fs.ls(ARCHIVE_VOLUME)
)

# %%
display(
    dbutils.fs.ls(XML_VOLUME)
)

# %%
spark.table(
    f"{CATALOG}.{BRONZE_SCHEMA}.ingestion_audit"
).printSchema()
