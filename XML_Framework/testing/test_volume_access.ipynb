# %%
xsd_path = "/Volumes/xml_framework/raw/xsd_volume/v1_orders.xsd"

print("XSD Path:", xsd_path)

# %%
import xml.etree.ElementTree as ET
tree = ET.parse(xsd_path)
root = tree.getroot()
display(root)

# %%
# Load parser notebook

# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/utils/xsd_parser.ipynb
# Load config

# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/notebooks/00_framework_config.ipynb

# %%
xsd_path = f"{XSD_VOLUME}/customer.xsd"

metadata_df = extract_metadata(xsd_path)

display(metadata_df)

# %%
# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/utils/xsd_parser

# %%
# Load utility notebooks
# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/utils/xsd_parser.ipynb
# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/utils/datatype_mapper.ipynb
# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/notebooks/00_framework_config.ipynb

# %%
xsd_path = f"{XSD_VOLUME}/v1_orders.xsd"

metadata_df = extract_metadata(xsd_path)

mapped_df = map_xsd_to_sql(metadata_df)

display(mapped_df)

# %%
#
# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/utils/xsd_parser.ipynb
# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/utils/datatype_mapper.ipynb
# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/notebooks/00_framework_config.ipynb
# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/utils/schema_registry.ipynb

# %%
xsd_path = f"{XSD_VOLUME}/v1_orders.xsd"

metadata_df = extract_metadata(xsd_path)

mapped_df = map_xsd_to_sql(metadata_df)

registry_df = enrich_registry_metadata(
    mapped_df,
    "customer.xsd"
)

display(registry_df)

# %%
# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/utils/ddl_generator

# %%
ddl = generate_ddl(
    metadata_df=registry_df,
    catalog=CATALOG,
    schema=BRONZE_SCHEMA,
    table_name="customer"
)

print(ddl)

# %%
# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/utils/table_creator

# %%
create_table(ddl)

# %%
table_exists(
    CATALOG,
    BRONZE_SCHEMA,
    "customer"
)

# %%
#
# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/notebooks/00_framework_config.ipynb

# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/utils/xml_reader.ipynb

# %%
xml_files = discover_xml_files(
    XML_VOLUME
)

xml_files

# %%
#
# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/notebooks/00_framework_config.ipynb

# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/utils/schema_resolver.ipynb

# %%
resolve_schema(
    "customer.xml",
    SCHEMA_REGISTRY_TABLE
)

# %%
display(
    spark.table(
        SCHEMA_REGISTRY_TABLE
    )
)

# %%
registry_df.write \
    .format("delta") \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .saveAsTable(
        SCHEMA_REGISTRY_TABLE
    )

# %%
spark.table(SCHEMA_REGISTRY_TABLE).printSchema()

# %%
#
# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/notebooks/00_framework_config.ipynb

# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/utils/xml_parser.ipynb

# %%
xml_path = f"{XML_VOLUME}/v1_order_1.xml"

# %%
xml_info = parse_xml(xml_path)

print(xml_info["file_name"])

print(xml_info["root_element"])

# %%
xml_path = f"{XML_VOLUME}/v1_order_1.xml"

# %%
xml_info = parse_xml(xml_path)

print(xml_info["file_name"])

print(xml_info["root_element"])

# %%
xml_info = parse_xml(xml_path)
display(xml_info)

# %%
#
# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/notebooks/00_framework_config.ipynb

# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/utils/schema_resolver.ipynb

# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/utils/xml_parser.ipynb

# %%
xml_info = parse_xml(
    f"{XML_VOLUME}/v1_order_1.xml"
)

schema_df = resolve_schema(
    xml_info["root_element"],
    SCHEMA_REGISTRY_TABLE
)

display(schema_df)

# %%
xml_info["root_element"]

# %%
display(
    spark.table(
        SCHEMA_REGISTRY_TABLE
    )
)

# %%
resolve_schema(
    xml_info["root_element"],
    SCHEMA_REGISTRY_TABLE
)

# %%
#
# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/notebooks/00_framework_config.ipynb

# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/utils/xml_parser.ipynb

# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/utils/xml_structure_explorer.ipynb

# %%
xml_info = parse_xml(f"{XML_VOLUME}/v1_order_1.xml")
structure=explore_xml_structure(xml_info["root"])
structure

# %%
#
# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/notebooks/00_framework_config.ipynb

# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/utils/xml_parser.ipynb

# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/utils/xml_flattener.ipynb

# %%
xml_info = parse_xml(f"{XML_VOLUME}/v1_order_1.xml")
root = xml_info["root"]

# %%
order_node = root.find("Order")

# %%
record = flatten_xml_element(
    order_node
)

display(record)

# %%
xml_info = parse_xml(
    f"{XML_VOLUME}/v1_order_1.xml"
)

records = flatten_orders(
    xml_info["root"]
)

display(records)

# %%
#
# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/notebooks/00_framework_config.ipynb

# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/utils/xml_parser.ipynb

# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/utils/xml_flattener.ipynb

# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/utils/dataframe_converter.ipynb

# %%
xml_info = parse_xml(
    f"{XML_VOLUME}/v1_order_1.xml"
)

records = flatten_orders(
    xml_info["root"]
)

df = records_to_dataframe(
    records
)

display(df)

# %%
#
# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/notebooks/00_framework_config.ipynb

# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/utils/xml_parser.ipynb

# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/utils/xml_flattener.ipynb

# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/utils/dataframe_converter.ipynb

# %run  /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/utils/delta_loader.ipynb

# %%
xml_info = parse_xml(f"{XML_VOLUME}/v1_order_1.xml")
records = flatten_orders(xml_info["root"])
df = records_to_dataframe(records)

# %%
load_to_delta(
    df=df,
    target_table=
        f"{CATALOG}.{BRONZE_SCHEMA}.v1_orders"
)

# %%
df.printSchema()

# %%
spark.table(
    f"{CATALOG}.{BRONZE_SCHEMA}.v1_orders"
).printSchema()

# %%
# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/utils/type_casting_engine

# %%
typed_df = apply_type_casting(
    df,
    f"{CATALOG}.{BRONZE_SCHEMA}.v1_orders"
)

typed_df.printSchema()

load_to_delta(
    df=typed_df,
    target_table=
        f"{CATALOG}.{BRONZE_SCHEMA}.v1_orders"
)

# %%
typed_df.printSchema()

# %%
display(typed_df)

# %%
display(
    spark.table(
        f"{CATALOG}.{BRONZE_SCHEMA}.v1_orders"
    )
)

# %%
spark.table(
    f"{CATALOG}.{BRONZE_SCHEMA}.v1_orders"
).count()

# %%
#
# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/utils/xsd_parser.ipynb

# %%
xsd_path = f"{XSD_VOLUME}/v1_orders.xsd"

# %%
metadata_df = extract_metadata(xsd_path)

display(metadata_df)

# %%
display(
    spark.table(
        SCHEMA_REGISTRY_TABLE
    )
)

# %%
display(
    spark.table(
        f"{CATALOG}.{BRONZE_SCHEMA}.v1_orders"
    )
)

# %%
#
# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/notebooks/00_framework_config.ipynb

# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/utils/xml_parser.ipynb

# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/utils/xml_flattener.ipynb

# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/utils/dataframe_converter.ipynb

# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/utils/type_casting_engine.ipynb

# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/utils/delta_loader.ipynb

# %%
xml_info = parse_xml(
    f"{XML_VOLUME}/v1_order_1.xml"
)

# %%
records = flatten_orders(
    xml_info["root"]
)

print(records)

# %%
df = records_to_dataframe(
    records
)

display(df)

# %%
typed_df = apply_type_casting(
    df,
    f"{CATALOG}.{BRONZE_SCHEMA}.v1_orders"
)

# %%
typed_df.printSchema()

# %%
load_to_delta(
    df=typed_df,
    target_table=
        f"{CATALOG}.{BRONZE_SCHEMA}.v1_orders"
)

# %%
display(
    spark.table(
        f"{CATALOG}.{BRONZE_SCHEMA}.v1_orders"
    )
)

# %%
spark.table(
    f"{CATALOG}.{BRONZE_SCHEMA}.v1_orders"
).count()

# %%
#
# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/notebooks/00_framework_config.ipynb

files = dbutils.fs.ls(XML_VOLUME)

for file in files:
    print(file.path)

# %%
xml_file = files[0].path

print(xml_file)

# %%
xml_content = dbutils.fs.head(
    xml_file,
    10000
)

print(xml_content[:500])

# %%
import xml.etree.ElementTree as ET

root = ET.fromstring(xml_content)

print(root.tag)

# %%
xml_info = parse_xml(
    files[0].path
)

print(xml_info["file_name"])

print(xml_info["root_element"])

# %%
display(
    spark.table(
        f"{CATALOG}.{BRONZE_SCHEMA}.v1_orders"
    )
)

# %%
from pyspark.sql.functions import count

display(
    spark.table(
        f"{CATALOG}.{BRONZE_SCHEMA}.v1_orders"
    )
    .groupBy("OrderId")
    .agg(
        count("*").alias("record_count")
    )
)

# %%
display(
    spark.table(
        f"{CATALOG}.{BRONZE_SCHEMA}.ingestion_audit"
    )
)

# %%
spark.table(
    f"{CATALOG}.{BRONZE_SCHEMA}.ingestion_audit"
).printSchema()

# %%
#
# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/utils/audit_logger.ipynb

# %%
log_ingestion(
    file_name="test.xml",
    target_table="v1_orders",
    record_count=1,
    status="SUCCESS",
    audit_table=f"{CATALOG}.{BRONZE_SCHEMA}.ingestion_audit"
)

# %%
spark.sql(f"""
DESCRIBE DETAIL
{CATALOG}.{BRONZE_SCHEMA}.ingestion_audit
""").display()

# %%
spark.table(
    f"{CATALOG}.{BRONZE_SCHEMA}.ingestion_audit"
).printSchema()

# %%
audit_df = spark.createDataFrame(
    [("test.xml","v1_orders",1,"SUCCESS")],
    ["file_name","target_table","record_count","status"]
)

from pyspark.sql.functions import current_timestamp

audit_df = audit_df.withColumn(
    "load_timestamp",
    current_timestamp()
)

audit_df.write \
    .format("delta") \
    .mode("append") \
    .saveAsTable(
        f"{CATALOG}.{BRONZE_SCHEMA}.ingestion_audit"
    )

# %%
spark.sql(f"""
DROP TABLE IF EXISTS
{CATALOG}.{BRONZE_SCHEMA}.ingestion_audit
""")

# %%
audit_df = spark.createDataFrame(
    [("test.xml","v1_orders",1,"SUCCESS")],
    ["file_name","target_table","record_count","status"]
)

from pyspark.sql.functions import current_timestamp

audit_df = audit_df.withColumn(
    "load_timestamp",
    current_timestamp()
)

audit_df.write \
    .format("delta") \
    .mode("append") \
    .saveAsTable(
        f"{CATALOG}.{BRONZE_SCHEMA}.ingestion_audit"
    )

# %%
spark.table(
    f"{CATALOG}.{BRONZE_SCHEMA}.ingestion_audit"
).printSchema()

# %%
#
# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/notebooks/00_framework_config.ipynb

# %%
log_ingestion(
    file_name="audit_test.xml",
    target_table="v1_orders",
    record_count=1,
    status="SUCCESS",
    audit_table=
        f"{CATALOG}.{BRONZE_SCHEMA}.ingestion_audit"
)

# %%
#
# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/notebooks/xml_pipeline_runner.ipynb

# %%
display(
    spark.table(
        f"{CATALOG}.{BRONZE_SCHEMA}.ingestion_audit"
    )
)

# %%
spark.sql(f"""
DESCRIBE DETAIL
{CATALOG}.{BRONZE_SCHEMA}.ingestion_audit
""").display()

# %%
spark.table(
    f"{CATALOG}.{BRONZE_SCHEMA}.ingestion_audit"
).printSchema()

# %%
spark.sql(f"""
DROP TABLE IF EXISTS
{CATALOG}.{BRONZE_SCHEMA}.ingestion_audit
""")

# %%
spark.table(
    f"{CATALOG}.{BRONZE_SCHEMA}.ingestion_audit"
).printSchema()

# %%
#
# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/utils/audit_logger.ipynb

log_ingestion(
    file_name="audit_test.xml",
    target_table="v1_orders",
    record_count=1,
    status="SUCCESS",
    audit_table=
        f"{CATALOG}.{BRONZE_SCHEMA}.ingestion_audit"
)

# %%
display(
    spark.table(
        f"{CATALOG}.{BRONZE_SCHEMA}.ingestion_audit"
    )
)

# %%
print(CATALOG)
print(BRONZE_SCHEMA)

# %%
spark.sql(f"""
SHOW TABLES IN {CATALOG}.{BRONZE_SCHEMA}
""")

# %%
display(
    spark.sql("""
    SHOW TABLES IN xml_framework.bronze
    """)
)

# %%
display(
    spark.table(
        f"{CATALOG}.{BRONZE_SCHEMA}.v1_orders"
    )
)

# %%
display(
    spark.table(
        f"{CATALOG}.{BRONZE_SCHEMA}.ingestion_audit"
    )
)

# %%
print(
    spark.table(
        f"{CATALOG}.{BRONZE_SCHEMA}.v1_orders"
    ).count()
)

# %%
print(
    spark.table(
        f"{CATALOG}.{BRONZE_SCHEMA}.ingestion_audit"
    ).count()
)

# %%
display(
    spark.table(
        f"{CATALOG}.{BRONZE_SCHEMA}.ingestion_audit"
    )
    .orderBy("load_timestamp")
)

# %%
#
# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/utils/file_already_processed.ipynb

# %%
is_file_processed(
    "v1_order_1.xml",
    f"{CATALOG}.{BRONZE_SCHEMA}.ingestion_audit"
)

# %%
is_file_processed(
    "dummy.xml",
    f"{CATALOG}.{BRONZE_SCHEMA}.ingestion_audit"
)

# %%
orders_after = spark.table(
    f"{CATALOG}.{BRONZE_SCHEMA}.v1_orders"
).count()

print(orders_after)

# %%
#
# %run /Workspace/Users/tejswi.tech2db@gmail.com/XML_Framework/notebooks/00_framework_config.ipynb

# %%
spark.sql(f"""
ALTER TABLE
{CATALOG}.{BRONZE_SCHEMA}.ingestion_audit
ADD COLUMNS
(
    error_message STRING
)
""")

# %%
spark.table(
    f"{CATALOG}.{BRONZE_SCHEMA}.ingestion_audit"
).printSchema()

# %%
display(
    spark.table(
        f"{CATALOG}.{BRONZE_SCHEMA}.ingestion_audit"
    )
)
