# %%
# %sql
CREATE CATALOG IF NOT EXISTS xml_framework;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS xml_framework.raw;
CREATE SCHEMA IF NOT EXISTS xml_framework.bronze;
CREATE SCHEMA IF NOT EXISTS xml_framework.silver;
CREATE SCHEMA IF NOT EXISTS xml_framework.config;

# %%
# %sql
CREATE VOLUME IF NOT EXISTS xml_framework.raw.xsd_volume;
CREATE VOLUME IF NOT EXISTS xml_framework.raw.xml_volume;
CREATE VOLUME IF NOT EXISTS xml_framework.raw.archive_volume;
